# %%
from skimage.io import imread
from glob import glob
import os
from pathlib import Path

# %%
data_path = Path("/home/jack/workspace/data/four-cell/output/frame_004")
imgs = [imread(str(img_path)) for img_path in data_path.glob("*.png")]
print(len(imgs))
# Out:
# 88

# %%
from cellpose import models
model = models.Cellpose(gpu=True, model_type="cyto3")

# %%
masks_pred, flows, styles, diams = model.eval(
            imgs,
            diameter=15,
            channels=[0, 0]
)
# Out:
# no seeds found in get_masks_torch - no masks found.

# %%
from cellpose import plot
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10, 10))
idx = 13
plot.show_segmentation(fig, imgs[idx], masks_pred[idx], flows[idx][0])

# %%
[(idx, n_nuclei) for idx, n_nuclei in enumerate(n_nuclei_list) if n_nuclei == 3]
