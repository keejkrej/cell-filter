# %%
from nd2reader import ND2Reader
import matplotlib.pyplot as plt

nd2_reader = ND2Reader('/mnt/e/20220525_MBAMB231.nd2')

image = nd2_reader.get_frame_2D(c=0, t=0, v=0)

# %%
image.shape
# Out:
# (2048, 2044)

# %%
plt.imshow(image, cmap='gray')
plt.show()
